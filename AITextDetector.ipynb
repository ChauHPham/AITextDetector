# %% [markdown]
# <a href="https://colab.research.google.com/github/ChauHPham/AITextDetector/blob/main/AITextDetector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install -q gradio huggingface_hub transformers torch pandas

# Clone repository (if not already done)
# !git clone https://github.com/ChauHPham/AITextDetector.git
# %cd AITextDetector

# Login to Hugging Face
from huggingface_hub import login
login()  # Paste your token when prompted

# Deploy!
# !gradio deploy
# Out:
# Cloning into 'AITextDetector'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 85 (delta 23), reused 73 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (85/85), 43.62 KiB | 10.90 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/AITextDetector/AITextDetector/AITextDetector/AITextDetector
# ...
# Need 'write' access token to create a Spaces repo.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
# ...
